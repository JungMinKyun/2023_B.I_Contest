# %%
# %cd '/content/drive/MyDrive/2023 겨울학기 + 여름학기/2023_B.I_Contest'
# Out:
# /content/drive/MyDrive/2023 겨울학기 + 여름학기/2023_B.I_Contest

# %%
# !echo "# 2023_B.I_Contest" >> README.md
# !git init
# !git config --global user.email "minkyun0418@gmail.com"
# !git config --global user.name "JungMinKyun"
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/2023 겨울학기 + 여름학기/2023_B.I_Contest/.git/
# [main 3c3ad5a] first commit
#  1 file changed, 1 insertion(+)

# %%
# !git remote rm origin

# %%
# !git remote add origin https://JungMinKyun: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@github.com/JungMinKyun/2023_B.I_Contest.git
# !git push -u origin main
# Out:
# error: remote origin already exists.
# To https://github.com/JungMinKyun/2023_B.I_Contest.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/JungMinKyun/2023_B.I_Contest.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
# To https://github.com/JungMinKyun/2023_B.I_Contest.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/JungMinKyun/2023_B.I_Contest.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# ...

# %%
# !git add .
# !git commit -m "setup"
# !git push

# %%
# !git pull
# Out:
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 10 (delta 0), reused 6 (delta 0), pack-reused 0
# Unpacking objects: 100% (10/10), 2.24 KiB | 38.00 KiB/s, done.
# From https://github.com/JungMinKyun/2023_BI_Contest
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main
# hint: You have divergent branches and need to specify how to reconcile them.
# hint: You can do so by running one of the following commands sometime before
# hint: your next pull:
# hint:
# hint:   git config pull.rebase false  # merge (the default strategy)
# hint:   git config pull.rebase true   # rebase
# hint:   git config pull.ff only       # fast-forward only
# hint:
# hint: You can replace "git config" with "git config --global" to set a default
# hint: preference for all repositories. You can also pass --rebase, --no-rebase,
# ...
